# %% [markdown]
# ## Training 3b

# %% [markdown]
# Train with more dense sampling for visualization in paragraphs 18-20

# %%
seed=2

# %%
# Import stuff
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import einops
import tqdm.notebook as tqdm

import random
import time

# from google.colab import drive
from pathlib import Path
import pickle
import os

import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px
import plotly.io as pio
pio.renderers.default = "colab"
import plotly.graph_objects as go

from torch.utils.data import DataLoader

from functools import *
import pandas as pd
import gc

# import comet_ml
import itertools

# %% [markdown]
# ## Support Functions

# %%
# A helper class to get access to intermediate activations (inspired by Garcon)
# It's a dummy module that is the identity function by default
# I can wrap any intermediate activation in a HookPoint and get a convenient 
# way to add PyTorch hooks
class HookPoint(nn.Module):
    def __init__(self):
        super().__init__()
        self.fwd_hooks = []
        self.bwd_hooks = []
    
    def give_name(self, name):
        # Called by the model at initialisation
        self.name = name
    
    def add_hook(self, hook, dir='fwd'):
        # Hook format is fn(activation, hook_name)
        # Change it into PyTorch hook format (this includes input and output, 
        # which are the same for a HookPoint)
        def full_hook(module, module_input, module_output):
            return hook(module_output, name=self.name)
        if dir=='fwd':
            handle = self.register_forward_hook(full_hook)
            self.fwd_hooks.append(handle)
        elif dir=='bwd':
            handle = self.register_backward_hook(full_hook)
            self.bwd_hooks.append(handle)
        else:
            raise ValueError(f"Invalid direction {dir}")
    
    def remove_hooks(self, dir='fwd'):
        if (dir=='fwd') or (dir=='both'):
            for hook in self.fwd_hooks:
                hook.remove()
            self.fwd_hooks = []
        if (dir=='bwd') or (dir=='both'):
            for hook in self.bwd_hooks:
                hook.remove()
            self.bwd_hooks = []
        if dir not in ['fwd', 'bwd', 'both']:
            raise ValueError(f"Invalid direction {dir}")
    
    def forward(self, x):
        return x

# %%
# Define network architecture
# I defined my own transformer from scratch so I'd fully understand each component 
# - I expect this wasn't necessary or particularly important, and a bunch of this 
# replicates existing PyTorch functionality

# Embed & Unembed
class Embed(nn.Module):
    def __init__(self, d_vocab, d_model):
        super().__init__()
        self.W_E = nn.Parameter(torch.randn(d_model, d_vocab)/np.sqrt(d_model))
    
    def forward(self, x):
        return torch.einsum('dbp -> bpd', self.W_E[:, x])

class Unembed(nn.Module):
    def __init__(self, d_vocab, d_model):
        super().__init__()
        self.W_U = nn.Parameter(torch.randn(d_model, d_vocab)/np.sqrt(d_vocab))
    
    def forward(self, x):
        return (x @ self.W_U)

# Positional Embeddings
class PosEmbed(nn.Module):
    def __init__(self, max_ctx, d_model):
        super().__init__()
        self.W_pos = nn.Parameter(torch.randn(max_ctx, d_model)/np.sqrt(d_model))
    
    def forward(self, x):
        return x+self.W_pos[:x.shape[-2]]

# LayerNorm
class LayerNorm(nn.Module):
    def __init__(self, d_model, epsilon = 1e-4, model=[None]):
        super().__init__()
        self.model = model
        self.w_ln = nn.Parameter(torch.ones(d_model))
        self.b_ln = nn.Parameter(torch.zeros(d_model))
        self.epsilon = epsilon
    
    def forward(self, x):
        if self.model[0].use_ln:
            x = x - x.mean(axis=-1)[..., None]
            x = x / (x.std(axis=-1)[..., None] + self.epsilon)
            x = x * self.w_ln
            x = x + self.b_ln
            return x
        else:
            return x

# Attention
class Attention(nn.Module):
    def __init__(self, d_model, num_heads, d_head, n_ctx, model):
        super().__init__()
        self.model = model
        self.W_K = nn.Parameter(torch.randn(num_heads, d_head, d_model)/np.sqrt(d_model))
        self.W_Q = nn.Parameter(torch.randn(num_heads, d_head, d_model)/np.sqrt(d_model))
        self.W_V = nn.Parameter(torch.randn(num_heads, d_head, d_model)/np.sqrt(d_model))
        self.W_O = nn.Parameter(torch.randn(d_model, d_head * num_heads)/np.sqrt(d_model))
        self.register_buffer('mask', torch.tril(torch.ones((n_ctx, n_ctx))))
        self.d_head = d_head
        self.hook_k = HookPoint()
        self.hook_q = HookPoint()
        self.hook_v = HookPoint()
        self.hook_z = HookPoint()
        self.hook_attn = HookPoint()
        self.hook_attn_pre = HookPoint()

    def forward(self, x):
        k = self.hook_k(torch.einsum('ihd,bpd->biph', self.W_K, x))
        q = self.hook_q(torch.einsum('ihd,bpd->biph', self.W_Q, x))
        v = self.hook_v(torch.einsum('ihd,bpd->biph', self.W_V, x))
        attn_scores_pre = torch.einsum('biph,biqh->biqp', k, q)
        attn_scores_masked = torch.tril(attn_scores_pre) - 1e10 * (1 - self.mask[:x.shape[-2], :x.shape[-2]])
        attn_matrix = self.hook_attn(F.softmax(self.hook_attn_pre(attn_scores_masked/np.sqrt(self.d_head)), dim=-1))
        z = self.hook_z(torch.einsum('biph,biqp->biqh', v, attn_matrix))
        z_flat = einops.rearrange(z, 'b i q h -> b q (i h)')
        out = torch.einsum('df,bqf->bqd', self.W_O, z_flat)
        return out

# MLP Layers
class MLP(nn.Module):
    def __init__(self, d_model, d_mlp, act_type, model):
        super().__init__()
        self.model = model
        self.W_in = nn.Parameter(torch.randn(d_mlp, d_model)/np.sqrt(d_model))
        self.b_in = nn.Parameter(torch.zeros(d_mlp))
        self.W_out = nn.Parameter(torch.randn(d_model, d_mlp)/np.sqrt(d_model))
        self.b_out = nn.Parameter(torch.zeros(d_model))
        self.act_type = act_type
        # self.ln = LayerNorm(d_mlp, model=self.model)
        self.hook_pre = HookPoint()
        self.hook_post = HookPoint()
        assert act_type in ['ReLU', 'GeLU']
        
    def forward(self, x):
        x = self.hook_pre(torch.einsum('md,bpd->bpm', self.W_in, x) + self.b_in)
        if self.act_type=='ReLU':
            x = F.relu(x)
        elif self.act_type=='GeLU':
            x = F.gelu(x)
        x = self.hook_post(x)
        x = torch.einsum('dm,bpm->bpd', self.W_out, x) + self.b_out
        return x

# Transformer Block
class TransformerBlock(nn.Module):
    def __init__(self, d_model, d_mlp, d_head, num_heads, n_ctx, act_type, model):
        super().__init__()
        self.model = model
        # self.ln1 = LayerNorm(d_model, model=self.model)
        self.attn = Attention(d_model, num_heads, d_head, n_ctx, model=self.model)
        # self.ln2 = LayerNorm(d_model, model=self.model)
        self.mlp = MLP(d_model, d_mlp, act_type, model=self.model)
        self.hook_attn_out = HookPoint()
        self.hook_mlp_out = HookPoint()
        self.hook_resid_pre = HookPoint()
        self.hook_resid_mid = HookPoint()
        self.hook_resid_post = HookPoint()
    
    def forward(self, x):
        x = self.hook_resid_mid(x + self.hook_attn_out(self.attn((self.hook_resid_pre(x)))))
        x = self.hook_resid_post(x + self.hook_mlp_out(self.mlp((x))))
        return x

# Full transformer
class Transformer(nn.Module):
    def __init__(self, num_layers, d_vocab, d_model, d_mlp, d_head, num_heads, n_ctx, act_type, use_cache=False, use_ln=True):
        super().__init__()
        self.cache = {}
        self.use_cache = use_cache

        self.embed = Embed(d_vocab, d_model)
        self.pos_embed = PosEmbed(n_ctx, d_model)
        self.blocks = nn.ModuleList([TransformerBlock(d_model, d_mlp, d_head, num_heads, n_ctx, act_type, model=[self]) for i in range(num_layers)])
        # self.ln = LayerNorm(d_model, model=[self])
        self.unembed = Unembed(d_vocab, d_model)
        self.use_ln = use_ln

        for name, module in self.named_modules():
            if type(module)==HookPoint:
                module.give_name(name)
    
    def forward(self, x):
        x = self.embed(x)
        x = self.pos_embed(x)
        for block in self.blocks:
            x = block(x)
        # x = self.ln(x)
        x = self.unembed(x)
        return x

    def set_use_cache(self, use_cache):
        self.use_cache = use_cache
    
    def hook_points(self):
        return [module for name, module in self.named_modules() if 'hook' in name]

    def remove_all_hooks(self):
        for hp in self.hook_points():
            hp.remove_hooks('fwd')
            hp.remove_hooks('bwd')
    
    def cache_all(self, cache, incl_bwd=False):
        # Caches all activations wrapped in a HookPoint
        def save_hook(tensor, name):
            cache[name] = tensor.detach()
        def save_hook_back(tensor, name):
            cache[name+'_grad'] = tensor[0].detach()
        for hp in self.hook_points():
            hp.add_hook(save_hook, 'fwd')
            if incl_bwd:
                hp.add_hook(save_hook_back, 'bwd')

# %%
# Helper functions
def cuda_memory():
    print(torch.cuda.memory_allocated()/1e9)

def cross_entropy_high_precision(logits, labels):
    # Shapes: batch x vocab, batch
    # Cast logits to float64 because log_softmax has a float32 underflow on overly 
    # confident data and can only return multiples of 1.2e-7 (the smallest float x
    # such that 1+x is different from 1 in float32). This leads to loss spikes 
    # and dodgy gradients
    logprobs = F.log_softmax(logits.to(torch.float64), dim=-1)
    prediction_logprobs = torch.gather(logprobs, index=labels[:, None], dim=-1)
    loss = -torch.mean(prediction_logprobs)
    return loss

def full_loss(model, data):
    # Take the final position only
    logits = model(data)[:, -1]
    labels = torch.tensor([fn(i, j) for i, j, _ in data]).to('cuda')
    return cross_entropy_high_precision(logits, labels)

def test_logits(logits, bias_correction=False, original_logits=None, mode='all'):
    # Calculates cross entropy loss of logits representing a batch of all p^2 
    # possible inputs
    # Batch dimension is assumed to be first
    if logits.shape[1]==p*p:
        logits = logits.T
    if logits.shape==torch.Size([p*p, p+1]):
        logits = logits[:, :-1]
    logits = logits.reshape(p*p, p)
    if bias_correction:
        # Applies bias correction - we correct for any missing bias terms, 
        # independent of the input, by centering the new logits along the batch 
        # dimension, and then adding the average original logits across all inputs
        logits = einops.reduce(original_logits - logits, 'batch ... -> ...', 'mean') + logits
    if mode=='train':
        return cross_entropy_high_precision(logits[is_train], labels[is_train])
    elif mode=='test':
        return cross_entropy_high_precision(logits[is_test], labels[is_test])
    elif mode=='all':
        return cross_entropy_high_precision(logits, labels)

def unflatten_first(tensor):
    if tensor.shape[0]==p*p:
        return einops.rearrange(tensor, '(x y) ... -> x y ...', x=p, y=p)
    else: 
        return tensor
def cos(x, y):
    return (x.dot(y))/x.norm()/y.norm()
def mod_div(a, b):
    return (a*pow(b, p-2, p))%p
def normalize(tensor, axis=0):
    return tensor/(tensor).pow(2).sum(keepdim=True, axis=axis).sqrt()
def extract_freq_2d(tensor, freq):
    # Takes in a pxpx... or batch x ... tensor, returns a 3x3x... tensor of the 
    # Linear and quadratic terms of frequency freq
    tensor = unflatten_first(tensor)
    # Extracts the linear and quadratic terms corresponding to frequency freq
    index_1d = [0, 2*freq-1, 2*freq]
    # Some dumb manipulation to use fancy array indexing rules
    # Gets the rows and columns in index_1d
    return tensor[[[i]*3 for i in index_1d], [index_1d]*3]
def get_cov(tensor, norm=True):
    # Calculate covariance matrix
    if norm:
        tensor = normalize(tensor, axis=1)
    return tensor @ tensor.T
def is_close(a, b):
    return ((a-b).pow(2).sum()/(a.pow(2).sum().sqrt())/(b.pow(2).sum().sqrt())).item()

# %%
def compute_frequency_components(m):
    """
    Compute canonical frequency components of a real 2D signal m using fft2.

    Returns:
        components: list of dicts with keys:
            - 'kx': frequency index in x (rows)
            - 'ky': frequency index in y (cols)
            - 'coeff': complex FFT coefficient at (kx, ky)
        Nx, Ny: dimensions of the input
    """
    m = np.asarray(m)
    Nx, Ny = m.shape
    F = np.fft.fft2(m)

    components = []
    seen = set()

    for kx in range(Nx):
        for ky in range(Ny):
            # Conjugate partner indices for real-valued input
            kx_conj = (-kx) % Nx
            ky_conj = (-ky) % Ny

            pair = tuple(sorted([(kx, ky), (kx_conj, ky_conj)]))
            if pair in seen:
                continue
            seen.add(pair)

            # Always store the "smaller" one in lexicographic order
            kx_rep, ky_rep = pair[0]
            coeff = F[kx_rep, ky_rep]
            components.append({
                "kx": kx_rep,
                "ky": ky_rep,
                "coeff": coeff
            })

    return components, Nx, Ny


def components_to_terms(components, Nx, Ny, num_freqs, include_dc=True):
    """
    Convert FFT components into real cosine terms with amplitude & phase.

    Args:
        components: output from compute_frequency_components
        Nx, Ny: grid size
        num_freqs: number of *non-DC* frequencies to keep
        include_dc: whether to include the constant (DC) term

    Returns:
        terms: list of dicts with keys:
            - 'kx', 'ky'
            - 'amplitude'  (real, >= 0)
            - 'phase'      (in radians)
            - 'is_dc'      (bool, True only for the constant term)
    """
    terms = []
    dc_term = None

    for c in components:
        kx = c["kx"]
        ky = c["ky"]
        coeff = c["coeff"]

        # DC component (constant offset)
        if kx == 0 and ky == 0:
            dc_value = coeff.real / (Nx * Ny)
            dc_term = {
                "kx": 0,
                "ky": 0,
                "amplitude": dc_value,  # directly the constant offset
                "phase": 0.0,
                "is_dc": True,
            }
        else:
            # For real signals, combine (k, l) and (-k, -l) into:
            #   2*|F|/(Nx*Ny) * cos(2π(kx i/Nx + ky j/Ny) + phase)
            amp = 2.0 * np.abs(coeff) / (Nx * Ny)
            phase = np.angle(coeff)
            terms.append({
                "kx": kx,
                "ky": ky,
                "amplitude": amp,
                "phase": phase,
                "is_dc": False,
            })

    # Sort non-DC terms by amplitude (largest first)
    terms.sort(key=lambda t: t["amplitude"], reverse=True)

    # Keep only the top num_freqs
    terms = terms[:num_freqs]

    # Optionally prepend DC term
    if include_dc and dc_term is not None:
        terms = [dc_term] + terms

    return terms

def generate_python_reconstructor(terms, Nx, Ny, func_name="recon_func", decimals=4):
    """
    Generate a Python function as a string that reconstructs the signal
    using explicit 1D and product-of-cosine terms from a sparse Fourier representation.

    Types of terms:
      - DC term (constant)
      - Row-only:   A * cos(2π * (kx*i/Nx) + φ)
      - Col-only:   B * cos(2π * (ky*j/Ny) + φ)
      - Product:    C * cos(2π * (kx*i/Nx) + φ) * cos(2π * (ky*j/Ny) + φ)

    You must have `import numpy as np` in the scope where you paste/run this.
    """
    lines = []
    lines.append(f"def {func_name}(i, j):")

    if not terms:
        lines.append("    return 0.0")
        return "\n".join(lines)

    # Separate DC from others
    dc_terms = [t for t in terms if t.get("is_dc", False)]
    non_dc_terms = [t for t in terms if not t.get("is_dc", False)]

    if dc_terms:
        dc_val = round(dc_terms[0]["amplitude"], decimals)
        lines.append(f"    val = {dc_val}")
    else:
        lines.append("    val = 0.0")

    for t in non_dc_terms:
        kx, ky = t["kx"], t["ky"]
        A = round(t["amplitude"], decimals)
        phi = round(t["phase"], decimals)

        if A == 0:
            continue

        if kx != 0 and ky == 0:
            # Row-only cosine
            line = (
                f"    val += {A} * np.cos(2*np.pi*(({kx}*i)/{Nx}) + {phi})"
            )
        elif kx == 0 and ky != 0:
            # Column-only cosine
            line = (
                f"    val += {A} * np.cos(2*np.pi*(({ky}*j)/{Ny}) + {phi})"
            )
        else:
            # Product-of-cosines term (your desired "third" type)
            line = (
                f"    val += {A} * np.cos(2*np.pi*(({kx}*i)/{Nx}) + {phi})"
                f" * np.cos(2*np.pi*(({ky}*j)/{Ny}) + {phi})"
            )

        lines.append(line)

    lines.append("    return val")

    return "\n".join(lines)

# %%
def set_seed(seed):
        torch.manual_seed(seed)
        torch.cuda.manual_seed_all(seed) # For all CUDA devices
        np.random.seed(seed)
        random.seed(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False # Set to False for determinism

# %%
def embedding_frequency_penalty(model: Transformer) -> torch.Tensor:
    """
    Encourage neighboring tokens in the embedding space to be similar.
    This is a graph-Laplacian-style smoothness penalty on W_E, which
    corresponds to penalizing high-frequency Fourier modes on Z_p.

    W_E has shape [d_model, d_vocab].
    We smooth along the vocab dimension (the modular arithmetic axis).
    """
    E = model.embed.W_E  # [d_model, d_vocab]

    # Differences between consecutive tokens (0-1, 1-2, ..., (V-2)-(V-1))
    diff = E[:, 1:] - E[:, :-1]  # [d_model, d_vocab-1]

    # Wrap-around difference to respect modular structure: token V-1 vs 0
    wrap = E[:, :1] - E[:, -1:]  # [d_model, 1]

    # Mean squared differences (Laplacian smoothness)
    penalty = (diff.pow(2).mean() + wrap.pow(2).mean())
    return penalty

# %% [markdown]
# ## Hyperparameters

# %%
root = Path('/home/stephen/grokking')
freq_penalty_weight = 1e-4 

frac_train=0.24 #0.28 might be more interesting than 0.3
p=113
# seed=2 ##Set at top

lr=1e-3 #@param
weight_decay = 1.0 #@param
p=113 #@param
d_model = 128 #@param
fn_name = 'add' #@param ['add', 'subtract', 'x2xyy2','rand']
num_epochs = 30000 #@param
save_models = True #@param
save_every = 10 # Maybe crank this down
# Stop training when test loss is <stopping_thresh
stopping_thresh = -1 #@param

num_layers = 1
batch_style = 'full'
d_vocab = p+1
n_ctx = 3
d_mlp = 4*d_model
num_heads = 4
assert d_model % num_heads == 0
d_head = d_model//num_heads
act_type = 'ReLU' #@param ['ReLU', 'GeLU']
# batch_size = 512
use_ln = False
random_answers = np.random.randint(low=0, high=p, size=(p, p))
fns_dict = {'add': lambda x,y:(x+y)%p, 'subtract': lambda x,y:(x-y)%p, 'x2xyy2':lambda x,y:(x**2+x*y+y**2)%p, 'rand':lambda x,y:random_answers[x][y]}
fn = fns_dict[fn_name]

# %%
frac_train, seed
# Out:
# (0.24, 2)

# %%
def gen_train_test(frac_train, num, seed=0):
    # Generate train and test split
    pairs = [(i, j, num) for i in range(num) for j in range(num)]
    random.seed(seed)
    random.shuffle(pairs)
    div = int(frac_train*len(pairs))
    return pairs[:div], pairs[div:]

train, test = gen_train_test(frac_train, p, seed)
print(len(train), len(test))
# Out:
# 3064 9705

# %%
# Creates an array of Boolean indices according to whether each data point is in 
# train or test
# Used to index into the big batch of all possible data
is_train = []
is_test = []
for x in range(p):
    for y in range(p):
        if (x, y, 113) in train:
            is_train.append(True)
            is_test.append(False)
        else:
            is_train.append(False)
            is_test.append(True)
is_train = np.array(is_train)
is_test = np.array(is_test)

# %% [markdown]
# ## Training Loop

# %%
set_seed(seed)
model = Transformer(num_layers=num_layers, d_vocab=d_vocab, d_model=d_model, d_mlp=d_mlp, d_head=d_head, num_heads=num_heads, n_ctx=n_ctx, act_type=act_type, use_cache=False, use_ln=use_ln)
model.to('cuda')
optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay, betas=(0.9, 0.98))
scheduler = optim.lr_scheduler.LambdaLR(optimizer, lambda step: min(step/10, 1))
run_name = f"grok_{int(time.time())}"
print(f'Run name {run_name}')
if save_models:
    os.mkdir(root/run_name)
    save_dict = {'model':model.state_dict(), 'train_data':train, 'test_data':test}
    torch.save(save_dict, root/run_name/'init.pth')
train_losses = []
test_losses = []
train_accs = []
test_accs = []
for epoch in range(num_epochs):

    # 1. Compute base cross-entropy losses (no regularization)
    train_ce_loss = full_loss(model, train)
    test_loss = full_loss(model, test)  # leave test as-is

    # 2. Compute smoothness / frequency penalty on embeddings
    freq_pen = embedding_frequency_penalty(model)

    # 3. Total train loss = CE + λ * penalty
    train_loss = train_ce_loss + freq_penalty_weight * freq_pen

    # 4. Track (usually you want to log CE only for grokking plots)
    train_losses.append(train_ce_loss.item())
    test_losses.append(test_loss.item())

    logits = model(train)[:, -1]
    labels = torch.tensor([fn(i, j) for i, j, _ in train]).to('cuda')
    train_acc=((logits.detach().cpu().argmax(1)==labels.detach().cpu()).sum()/len(labels)).item()
    train_accs.append(train_acc)
    
    logits = model(test)[:, -1]
    labels = torch.tensor([fn(i, j) for i, j, _ in test]).to('cuda')
    test_acc=((logits.detach().cpu().argmax(1)==labels.detach().cpu()).sum()/len(labels)).item()
    test_accs.append(test_acc)

    if epoch % 100 == 0:
        print(
            f"{epoch}_"
            f"{np.log(train_ce_loss.item()):.4f}_"
            f"{np.log(test_loss.item()):.4f}_"
            f"pen={freq_pen.item():.3e}"
        )

    # 5. Backprop / step
    train_loss.backward()
    optimizer.step()
    scheduler.step()
    optimizer.zero_grad()
    if test_loss.item() < stopping_thresh:
        break
    if (save_models) and (epoch%save_every == 0):
        if test_loss.item() < stopping_thresh:
            break
        save_dict = {
            'model': model.state_dict(),
            'optimizer': optimizer.state_dict(),
            'scheduler': scheduler.state_dict(),
            'train_loss': train_loss,
            'test_loss': test_loss,
            'epoch': epoch,
        }
        torch.save(save_dict, root/run_name/f"{epoch}.pth")
        print(f"Saved model to {root/run_name/f'{epoch}.pth'}")
if not save_models:
    os.mkdir(root/run_name)
save_dict = {
    'model': model.state_dict(),
    'optimizer': optimizer.state_dict(),
    'scheduler': scheduler.state_dict(),
    'train_loss': train_loss,
    'test_loss': test_loss,
    'train_losses': train_losses,
    'test_losses': test_losses,
    'epoch': epoch,
}
torch.save(save_dict, root/run_name/f"final.pth")
print(f"Saved model to {root/run_name/f'final.pth'}")

# save_models = False
# Out:
# Run name grok_1764602090
# 0_1.5603_1.5599_pen=3.216e-02
# Saved model to /home/stephen/grokking/grok_1764602090/0.pth
# Saved model to /home/stephen/grokking/grok_1764602090/10.pth
# Saved model to /home/stephen/grokking/grok_1764602090/20.pth
# Saved model to /home/stephen/grokking/grok_1764602090/30.pth
# Saved model to /home/stephen/grokking/grok_1764602090/40.pth
# Saved model to /home/stephen/grokking/grok_1764602090/50.pth
# Saved model to /home/stephen/grokking/grok_1764602090/60.pth
# Saved model to /home/stephen/grokking/grok_1764602090/70.pth
# Saved model to /home/stephen/grokking/grok_1764602090/80.pth
# Saved model to /home/stephen/grokking/grok_1764602090/90.pth
# 100_0.6096_2.1537_pen=5.503e-02
# Saved model to /home/stephen/grokking/grok_1764602090/100.pth
# Saved model to /home/stephen/grokking/grok_1764602090/110.pth
# Saved model to /home/stephen/grokking/grok_1764602090/120.pth
# Saved model to /home/stephen/grokking/grok_1764602090/130.pth
# Saved model to /home/stephen/grokking/grok_1764602090/140.pth
# Saved model to /home/stephen/grokking/grok_1764602090/150.pth
# Saved model to /home/stephen/grokking/grok_1764602090/160.pth
# Saved model to /home/stephen/grokking/grok_1764602090/170.pth
# Saved model to /home/stephen/grokking/grok_1764602090/180.pth
# Saved model to /home/stephen/grokking/grok_1764602090/190.pth
# 200_-4.1147_2.8488_pen=7.619e-02
# Saved model to /home/stephen/grokking/grok_1764602090/200.pth
# Saved model to /home/stephen/grokking/grok_1764602090/210.pth
# Saved model to /home/stephen/grokking/grok_1764602090/220.pth
# Saved model to /home/stephen/grokking/grok_1764602090/230.pth
# Saved model to /home/stephen/grokking/grok_1764602090/240.pth
# Saved model to /home/stephen/grokking/grok_1764602090/250.pth
# Saved model to /home/stephen/grokking/grok_1764602090/260.pth
# Saved model to /home/stephen/grokking/grok_1764602090/270.pth
# Saved model to /home/stephen/grokking/grok_1764602090/280.pth
# Saved model to /home/stephen/grokking/grok_1764602090/290.pth
# 300_-5.1633_2.8840_pen=7.667e-02
# Saved model to /home/stephen/grokking/grok_1764602090/300.pth
# Saved model to /home/stephen/grokking/grok_1764602090/310.pth
# Saved model to /home/stephen/grokking/grok_1764602090/320.pth
# Saved model to /home/stephen/grokking/grok_1764602090/330.pth
# Saved model to /home/stephen/grokking/grok_1764602090/340.pth
# Saved model to /home/stephen/grokking/grok_1764602090/350.pth
# Saved model to /home/stephen/grokking/grok_1764602090/360.pth
# Saved model to /home/stephen/grokking/grok_1764602090/370.pth
# Saved model to /home/stephen/grokking/grok_1764602090/380.pth
# Saved model to /home/stephen/grokking/grok_1764602090/390.pth
# 400_-6.2899_2.9422_pen=7.743e-02
# Saved model to /home/stephen/grokking/grok_1764602090/400.pth
# Saved model to /home/stephen/grokking/grok_1764602090/410.pth
# Saved model to /home/stephen/grokking/grok_1764602090/420.pth
# Saved model to /home/stephen/grokking/grok_1764602090/430.pth
# Saved model to /home/stephen/grokking/grok_1764602090/440.pth
# Saved model to /home/stephen/grokking/grok_1764602090/450.pth
# Saved model to /home/stephen/grokking/grok_1764602090/460.pth
# Saved model to /home/stephen/grokking/grok_1764602090/470.pth
# Saved model to /home/stephen/grokking/grok_1764602090/480.pth
# Saved model to /home/stephen/grokking/grok_1764602090/490.pth
# 500_-7.3932_3.0019_pen=7.798e-02
# Saved model to /home/stephen/grokking/grok_1764602090/500.pth
# Saved model to /home/stephen/grokking/grok_1764602090/510.pth
# Saved model to /home/stephen/grokking/grok_1764602090/520.pth
# Saved model to /home/stephen/grokking/grok_1764602090/530.pth
# Saved model to /home/stephen/grokking/grok_1764602090/540.pth
# Saved model to /home/stephen/grokking/grok_1764602090/550.pth
# Saved model to /home/stephen/grokking/grok_1764602090/560.pth
# Saved model to /home/stephen/grokking/grok_1764602090/570.pth
# Saved model to /home/stephen/grokking/grok_1764602090/580.pth
# Saved model to /home/stephen/grokking/grok_1764602090/590.pth
# 600_-8.4814_3.0612_pen=7.785e-02
# Saved model to /home/stephen/grokking/grok_1764602090/600.pth
# Saved model to /home/stephen/grokking/grok_1764602090/610.pth
# Saved model to /home/stephen/grokking/grok_1764602090/620.pth
# Saved model to /home/stephen/grokking/grok_1764602090/630.pth
# Saved model to /home/stephen/grokking/grok_1764602090/640.pth
# Saved model to /home/stephen/grokking/grok_1764602090/650.pth
# Saved model to /home/stephen/grokking/grok_1764602090/660.pth
# Saved model to /home/stephen/grokking/grok_1764602090/670.pth
# Saved model to /home/stephen/grokking/grok_1764602090/680.pth
# Saved model to /home/stephen/grokking/grok_1764602090/690.pth
# 700_-9.5514_3.1191_pen=7.617e-02
# Saved model to /home/stephen/grokking/grok_1764602090/700.pth
# Saved model to /home/stephen/grokking/grok_1764602090/710.pth
# Saved model to /home/stephen/grokking/grok_1764602090/720.pth
# Saved model to /home/stephen/grokking/grok_1764602090/730.pth
# Saved model to /home/stephen/grokking/grok_1764602090/740.pth
# Saved model to /home/stephen/grokking/grok_1764602090/750.pth
# Saved model to /home/stephen/grokking/grok_1764602090/760.pth
# Saved model to /home/stephen/grokking/grok_1764602090/770.pth
# Saved model to /home/stephen/grokking/grok_1764602090/780.pth
# Saved model to /home/stephen/grokking/grok_1764602090/790.pth
# 800_-10.6038_3.1745_pen=7.148e-02
# Saved model to /home/stephen/grokking/grok_1764602090/800.pth
# Saved model to /home/stephen/grokking/grok_1764602090/810.pth
# Saved model to /home/stephen/grokking/grok_1764602090/820.pth
# Saved model to /home/stephen/grokking/grok_1764602090/830.pth
# Saved model to /home/stephen/grokking/grok_1764602090/840.pth
# Saved model to /home/stephen/grokking/grok_1764602090/850.pth
# Saved model to /home/stephen/grokking/grok_1764602090/860.pth
# Saved model to /home/stephen/grokking/grok_1764602090/870.pth
# Saved model to /home/stephen/grokking/grok_1764602090/880.pth
# Saved model to /home/stephen/grokking/grok_1764602090/890.pth
# 900_-11.6211_3.2265_pen=6.257e-02
# Saved model to /home/stephen/grokking/grok_1764602090/900.pth
# Saved model to /home/stephen/grokking/grok_1764602090/910.pth
# Saved model to /home/stephen/grokking/grok_1764602090/920.pth
# Saved model to /home/stephen/grokking/grok_1764602090/930.pth
# Saved model to /home/stephen/grokking/grok_1764602090/940.pth
# Saved model to /home/stephen/grokking/grok_1764602090/950.pth
# Saved model to /home/stephen/grokking/grok_1764602090/960.pth
# Saved model to /home/stephen/grokking/grok_1764602090/970.pth
# Saved model to /home/stephen/grokking/grok_1764602090/980.pth
# Saved model to /home/stephen/grokking/grok_1764602090/990.pth
# 1000_-12.5740_3.2727_pen=5.153e-02
# Saved model to /home/stephen/grokking/grok_1764602090/1000.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1010.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1020.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1030.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1040.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1050.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1060.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1070.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1080.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1090.pth
# 1100_-13.4078_3.3112_pen=4.300e-02
# Saved model to /home/stephen/grokking/grok_1764602090/1100.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1110.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1120.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1130.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1140.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1150.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1160.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1170.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1180.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1190.pth
# 1200_-14.0421_3.3378_pen=3.759e-02
# Saved model to /home/stephen/grokking/grok_1764602090/1200.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1210.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1220.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1230.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1240.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1250.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1260.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1270.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1280.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1290.pth
# 1300_-14.4374_3.3528_pen=3.238e-02
# Saved model to /home/stephen/grokking/grok_1764602090/1300.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1310.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1320.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1330.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1340.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1350.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1360.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1370.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1380.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1390.pth
# 1400_-14.6381_3.3590_pen=2.787e-02
# Saved model to /home/stephen/grokking/grok_1764602090/1400.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1410.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1420.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1430.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1440.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1450.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1460.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1470.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1480.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1490.pth
# 1500_-14.7242_3.3589_pen=2.482e-02
# Saved model to /home/stephen/grokking/grok_1764602090/1500.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1510.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1520.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1530.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1540.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1550.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1560.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1570.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1580.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1590.pth
# 1600_-14.7630_3.3559_pen=2.297e-02
# Saved model to /home/stephen/grokking/grok_1764602090/1600.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1610.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1620.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1630.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1640.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1650.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1660.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1670.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1680.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1690.pth
# 1700_-14.7821_3.3517_pen=2.185e-02
# Saved model to /home/stephen/grokking/grok_1764602090/1700.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1710.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1720.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1730.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1740.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1750.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1760.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1770.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1780.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1790.pth
# 1800_-14.7952_3.3469_pen=2.112e-02
# Saved model to /home/stephen/grokking/grok_1764602090/1800.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1810.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1820.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1830.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1840.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1850.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1860.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1870.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1880.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1890.pth
# 1900_-14.8032_3.3419_pen=2.061e-02
# Saved model to /home/stephen/grokking/grok_1764602090/1900.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1910.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1920.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1930.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1940.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1950.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1960.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1970.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1980.pth
# Saved model to /home/stephen/grokking/grok_1764602090/1990.pth
# 2000_-14.8129_3.3367_pen=2.025e-02
# Saved model to /home/stephen/grokking/grok_1764602090/2000.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2010.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2020.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2030.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2040.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2050.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2060.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2070.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2080.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2090.pth
# 2100_-14.8202_3.3315_pen=1.997e-02
# Saved model to /home/stephen/grokking/grok_1764602090/2100.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2110.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2120.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2130.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2140.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2150.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2160.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2170.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2180.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2190.pth
# 2200_-14.8273_3.3263_pen=1.973e-02
# Saved model to /home/stephen/grokking/grok_1764602090/2200.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2210.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2220.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2230.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2240.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2250.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2260.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2270.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2280.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2290.pth
# 2300_-14.8331_3.3210_pen=1.953e-02
# Saved model to /home/stephen/grokking/grok_1764602090/2300.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2310.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2320.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2330.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2340.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2350.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2360.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2370.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2380.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2390.pth
# 2400_-14.8384_3.3157_pen=1.934e-02
# Saved model to /home/stephen/grokking/grok_1764602090/2400.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2410.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2420.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2430.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2440.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2450.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2460.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2470.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2480.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2490.pth
# 2500_-14.8421_3.3103_pen=1.917e-02
# Saved model to /home/stephen/grokking/grok_1764602090/2500.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2510.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2520.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2530.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2540.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2550.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2560.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2570.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2580.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2590.pth
# 2600_-14.8497_3.3044_pen=1.901e-02
# Saved model to /home/stephen/grokking/grok_1764602090/2600.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2610.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2620.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2630.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2640.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2650.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2660.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2670.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2680.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2690.pth
# 2700_-14.8542_3.2987_pen=1.885e-02
# Saved model to /home/stephen/grokking/grok_1764602090/2700.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2710.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2720.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2730.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2740.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2750.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2760.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2770.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2780.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2790.pth
# 2800_-14.8593_3.2927_pen=1.869e-02
# Saved model to /home/stephen/grokking/grok_1764602090/2800.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2810.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2820.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2830.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2840.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2850.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2860.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2870.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2880.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2890.pth
# 2900_-14.8632_3.2865_pen=1.854e-02
# Saved model to /home/stephen/grokking/grok_1764602090/2900.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2910.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2920.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2930.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2940.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2950.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2960.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2970.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2980.pth
# Saved model to /home/stephen/grokking/grok_1764602090/2990.pth
# 3000_-14.8682_3.2801_pen=1.839e-02
# Saved model to /home/stephen/grokking/grok_1764602090/3000.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3010.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3020.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3030.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3040.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3050.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3060.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3070.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3080.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3090.pth
# 3100_-14.8729_3.2737_pen=1.824e-02
# Saved model to /home/stephen/grokking/grok_1764602090/3100.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3110.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3120.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3130.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3140.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3150.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3160.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3170.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3180.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3190.pth
# 3200_-14.8768_3.2671_pen=1.810e-02
# Saved model to /home/stephen/grokking/grok_1764602090/3200.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3210.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3220.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3230.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3240.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3250.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3260.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3270.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3280.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3290.pth
# 3300_-14.8827_3.2605_pen=1.796e-02
# Saved model to /home/stephen/grokking/grok_1764602090/3300.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3310.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3320.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3330.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3340.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3350.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3360.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3370.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3380.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3390.pth
# 3400_-14.8872_3.2535_pen=1.783e-02
# Saved model to /home/stephen/grokking/grok_1764602090/3400.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3410.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3420.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3430.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3440.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3450.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3460.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3470.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3480.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3490.pth
# 3500_-14.8895_3.2464_pen=1.769e-02
# Saved model to /home/stephen/grokking/grok_1764602090/3500.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3510.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3520.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3530.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3540.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3550.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3560.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3570.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3580.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3590.pth
# 3600_-14.8948_3.2388_pen=1.755e-02
# Saved model to /home/stephen/grokking/grok_1764602090/3600.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3610.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3620.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3630.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3640.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3650.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3660.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3670.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3680.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3690.pth
# 3700_-14.8983_3.2308_pen=1.741e-02
# Saved model to /home/stephen/grokking/grok_1764602090/3700.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3710.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3720.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3730.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3740.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3750.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3760.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3770.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3780.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3790.pth
# 3800_-14.9026_3.2230_pen=1.728e-02
# Saved model to /home/stephen/grokking/grok_1764602090/3800.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3810.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3820.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3830.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3840.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3850.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3860.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3870.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3880.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3890.pth
# 3900_-14.9086_3.2142_pen=1.714e-02
# Saved model to /home/stephen/grokking/grok_1764602090/3900.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3910.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3920.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3930.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3940.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3950.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3960.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3970.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3980.pth
# Saved model to /home/stephen/grokking/grok_1764602090/3990.pth
# 4000_-14.9135_3.2049_pen=1.700e-02
# Saved model to /home/stephen/grokking/grok_1764602090/4000.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4010.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4020.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4030.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4040.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4050.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4060.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4070.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4080.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4090.pth
# 4100_-14.9160_3.1953_pen=1.686e-02
# Saved model to /home/stephen/grokking/grok_1764602090/4100.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4110.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4120.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4130.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4140.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4150.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4160.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4170.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4180.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4190.pth
# 4200_-14.9221_3.1846_pen=1.672e-02
# Saved model to /home/stephen/grokking/grok_1764602090/4200.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4210.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4220.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4230.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4240.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4250.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4260.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4270.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4280.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4290.pth
# 4300_-14.9267_3.1733_pen=1.657e-02
# Saved model to /home/stephen/grokking/grok_1764602090/4300.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4310.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4320.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4330.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4340.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4350.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4360.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4370.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4380.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4390.pth
# 4400_-14.9293_3.1618_pen=1.643e-02
# Saved model to /home/stephen/grokking/grok_1764602090/4400.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4410.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4420.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4430.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4440.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4450.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4460.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4470.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4480.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4490.pth
# 4500_-14.9340_3.1491_pen=1.628e-02
# Saved model to /home/stephen/grokking/grok_1764602090/4500.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4510.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4520.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4530.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4540.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4550.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4560.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4570.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4580.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4590.pth
# 4600_-14.9416_3.1361_pen=1.613e-02
# Saved model to /home/stephen/grokking/grok_1764602090/4600.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4610.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4620.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4630.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4640.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4650.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4660.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4670.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4680.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4690.pth
# 4700_-14.9463_3.1222_pen=1.598e-02
# Saved model to /home/stephen/grokking/grok_1764602090/4700.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4710.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4720.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4730.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4740.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4750.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4760.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4770.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4780.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4790.pth
# 4800_-14.9512_3.1071_pen=1.582e-02
# Saved model to /home/stephen/grokking/grok_1764602090/4800.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4810.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4820.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4830.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4840.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4850.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4860.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4870.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4880.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4890.pth
# 4900_-14.9566_3.0910_pen=1.565e-02
# Saved model to /home/stephen/grokking/grok_1764602090/4900.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4910.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4920.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4930.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4940.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4950.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4960.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4970.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4980.pth
# Saved model to /home/stephen/grokking/grok_1764602090/4990.pth
# 5000_-14.9629_3.0738_pen=1.549e-02
# Saved model to /home/stephen/grokking/grok_1764602090/5000.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5010.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5020.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5030.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5040.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5050.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5060.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5070.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5080.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5090.pth
# 5100_-14.9677_3.0551_pen=1.532e-02
# Saved model to /home/stephen/grokking/grok_1764602090/5100.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5110.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5120.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5130.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5140.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5150.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5160.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5170.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5180.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5190.pth
# 5200_-14.9732_3.0346_pen=1.514e-02
# Saved model to /home/stephen/grokking/grok_1764602090/5200.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5210.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5220.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5230.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5240.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5250.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5260.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5270.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5280.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5290.pth
# 5300_-14.9803_3.0125_pen=1.496e-02
# Saved model to /home/stephen/grokking/grok_1764602090/5300.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5310.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5320.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5330.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5340.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5350.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5360.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5370.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5380.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5390.pth
# 5400_-14.9843_2.9898_pen=1.477e-02
# Saved model to /home/stephen/grokking/grok_1764602090/5400.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5410.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5420.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5430.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5440.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5450.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5460.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5470.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5480.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5490.pth
# 5500_-14.9916_2.9661_pen=1.459e-02
# Saved model to /home/stephen/grokking/grok_1764602090/5500.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5510.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5520.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5530.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5540.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5550.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5560.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5570.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5580.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5590.pth
# 5600_-15.0003_2.9409_pen=1.440e-02
# Saved model to /home/stephen/grokking/grok_1764602090/5600.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5610.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5620.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5630.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5640.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5650.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5660.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5670.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5680.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5690.pth
# 5700_-15.0080_2.9132_pen=1.420e-02
# Saved model to /home/stephen/grokking/grok_1764602090/5700.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5710.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5720.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5730.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5740.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5750.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5760.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5770.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5780.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5790.pth
# 5800_-15.0130_2.8831_pen=1.399e-02
# Saved model to /home/stephen/grokking/grok_1764602090/5800.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5810.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5820.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5830.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5840.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5850.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5860.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5870.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5880.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5890.pth
# 5900_-15.0219_2.8513_pen=1.378e-02
# Saved model to /home/stephen/grokking/grok_1764602090/5900.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5910.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5920.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5930.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5940.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5950.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5960.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5970.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5980.pth
# Saved model to /home/stephen/grokking/grok_1764602090/5990.pth
# 6000_-15.0304_2.8185_pen=1.356e-02
# Saved model to /home/stephen/grokking/grok_1764602090/6000.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6010.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6020.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6030.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6040.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6050.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6060.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6070.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6080.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6090.pth
# 6100_-15.0361_2.7824_pen=1.333e-02
# Saved model to /home/stephen/grokking/grok_1764602090/6100.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6110.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6120.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6130.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6140.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6150.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6160.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6170.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6180.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6190.pth
# 6200_-15.0450_2.7439_pen=1.310e-02
# Saved model to /home/stephen/grokking/grok_1764602090/6200.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6210.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6220.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6230.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6240.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6250.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6260.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6270.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6280.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6290.pth
# 6300_-15.0543_2.7031_pen=1.286e-02
# Saved model to /home/stephen/grokking/grok_1764602090/6300.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6310.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6320.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6330.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6340.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6350.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6360.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6370.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6380.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6390.pth
# 6400_-15.0625_2.6588_pen=1.261e-02
# Saved model to /home/stephen/grokking/grok_1764602090/6400.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6410.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6420.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6430.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6440.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6450.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6460.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6470.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6480.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6490.pth
# 6500_-15.0727_2.6120_pen=1.236e-02
# Saved model to /home/stephen/grokking/grok_1764602090/6500.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6510.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6520.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6530.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6540.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6550.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6560.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6570.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6580.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6590.pth
# 6600_-15.0844_2.5611_pen=1.210e-02
# Saved model to /home/stephen/grokking/grok_1764602090/6600.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6610.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6620.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6630.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6640.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6650.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6660.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6670.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6680.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6690.pth
# 6700_-15.0925_2.5063_pen=1.183e-02
# Saved model to /home/stephen/grokking/grok_1764602090/6700.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6710.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6720.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6730.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6740.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6750.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6760.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6770.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6780.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6790.pth
# 6800_-15.1049_2.4467_pen=1.155e-02
# Saved model to /home/stephen/grokking/grok_1764602090/6800.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6810.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6820.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6830.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6840.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6850.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6860.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6870.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6880.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6890.pth
# 6900_-15.1108_2.3819_pen=1.127e-02
# Saved model to /home/stephen/grokking/grok_1764602090/6900.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6910.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6920.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6930.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6940.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6950.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6960.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6970.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6980.pth
# Saved model to /home/stephen/grokking/grok_1764602090/6990.pth
# 7000_-15.1283_2.3092_pen=1.097e-02
# Saved model to /home/stephen/grokking/grok_1764602090/7000.pth
# Saved model to /home/stephen/grokking/grok_1764602090/7010.pth
# Saved model to /home/stephen/grokking/grok_1764602090/7020.pth
# Saved model to /home/stephen/grokking/grok_1764602090/7030.pth
# Saved model to /home/stephen/grokking/grok_1764602090/7040.pth
# Saved model to /home/stephen/grokking/grok_1764602090/7050.pth
# Saved model to /home/stephen/grokking/grok_1764602090/7060.pth
# Saved model to /home/stephen/grokking/grok_1764602090/7070.pth
# Saved model to /home/stephen/grokking/grok_1764602090/7080.pth
# Saved model to /home/stephen/grokking/grok_1764602090/7090.pth
# 7100_-15.1403_2.2278_pen=1.065e-02
# Saved model to /home/stephen/grokking/grok_1764602090/7100.pth
# Saved model to /home/stephen/grokking/grok_1764602090/7110.pth
# Saved model to /home/stephen/grokking/grok_1764602090/7120.pth
# Saved model to /home/stephen/grokking/grok_1764602090/7130.pth
# Saved model to /home/stephen/grokking/grok_1764602090/7140.pth
# Saved model to /home/stephen/grokking/grok_1764602090/7150.pth
# Saved model to /home/stephen/grokking/grok_1764602090/7160.pth
# Saved model to /home/stephen/grokking/grok_1764602090/7170.pth
# Saved model to /home/stephen/grokking/grok_1764602090/7180.pth
# Saved model to /home/stephen/grokking/grok_1764602090/7190.pth
# 7200_-15.1577_2.1348_pen=1.033e-02
# Saved model to /home/stephen/grokking/grok_1764602090/7200.pth
# Saved model to /home/stephen/grokking/grok_1764602090/7210.pth
# Saved model to /home/stephen/grokking/grok_1764602090/7220.pth
# ...
# Saved model to /home/stephen/grokking/grok_1764602090/27650.pth
# Saved model to /home/stephen/grokking/grok_1764602090/27660.pth
# Saved model to /home/stephen/grokking/grok_1764602090/27670.pth
# Saved model to /home/stephen/grokking/grok_1764602090/27680.pth
# Saved model to /home/stephen/grokking/grok_1764602090/27690.pth
# 27700_-16.0314_-12.2761_pen=3.148e-03
# Saved model to /home/stephen/grokking/grok_1764602090/27700.pth
# Saved model to /home/stephen/grokking/grok_1764602090/27710.pth
# Saved model to /home/stephen/grokking/grok_1764602090/27720.pth
# Saved model to /home/stephen/grokking/grok_1764602090/27730.pth
# Saved model to /home/stephen/grokking/grok_1764602090/27740.pth
# Saved model to /home/stephen/grokking/grok_1764602090/27750.pth
# Saved model to /home/stephen/grokking/grok_1764602090/27760.pth
# Saved model to /home/stephen/grokking/grok_1764602090/27770.pth
# Saved model to /home/stephen/grokking/grok_1764602090/27780.pth
# Saved model to /home/stephen/grokking/grok_1764602090/27790.pth
# 27800_-16.0314_-12.2951_pen=3.146e-03
# Saved model to /home/stephen/grokking/grok_1764602090/27800.pth
# Saved model to /home/stephen/grokking/grok_1764602090/27810.pth
# Saved model to /home/stephen/grokking/grok_1764602090/27820.pth
# Saved model to /home/stephen/grokking/grok_1764602090/27830.pth
# Saved model to /home/stephen/grokking/grok_1764602090/27840.pth
# Saved model to /home/stephen/grokking/grok_1764602090/27850.pth
# Saved model to /home/stephen/grokking/grok_1764602090/27860.pth
# Saved model to /home/stephen/grokking/grok_1764602090/27870.pth
# Saved model to /home/stephen/grokking/grok_1764602090/27880.pth
# Saved model to /home/stephen/grokking/grok_1764602090/27890.pth
# 27900_-16.0321_-12.2526_pen=3.144e-03
# Saved model to /home/stephen/grokking/grok_1764602090/27900.pth
# Saved model to /home/stephen/grokking/grok_1764602090/27910.pth
# Saved model to /home/stephen/grokking/grok_1764602090/27920.pth
# Saved model to /home/stephen/grokking/grok_1764602090/27930.pth
# Saved model to /home/stephen/grokking/grok_1764602090/27940.pth
# Saved model to /home/stephen/grokking/grok_1764602090/27950.pth
# Saved model to /home/stephen/grokking/grok_1764602090/27960.pth
# Saved model to /home/stephen/grokking/grok_1764602090/27970.pth
# Saved model to /home/stephen/grokking/grok_1764602090/27980.pth
# Saved model to /home/stephen/grokking/grok_1764602090/27990.pth
# 28000_-16.0321_-12.2438_pen=3.142e-03
# Saved model to /home/stephen/grokking/grok_1764602090/28000.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28010.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28020.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28030.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28040.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28050.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28060.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28070.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28080.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28090.pth
# 28100_-16.0321_-12.2227_pen=3.140e-03
# Saved model to /home/stephen/grokking/grok_1764602090/28100.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28110.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28120.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28130.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28140.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28150.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28160.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28170.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28180.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28190.pth
# 28200_-16.0319_-12.2047_pen=3.138e-03
# Saved model to /home/stephen/grokking/grok_1764602090/28200.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28210.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28220.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28230.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28240.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28250.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28260.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28270.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28280.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28290.pth
# 28300_-16.0323_-12.1738_pen=3.137e-03
# Saved model to /home/stephen/grokking/grok_1764602090/28300.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28310.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28320.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28330.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28340.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28350.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28360.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28370.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28380.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28390.pth
# 28400_-16.0324_-12.2336_pen=3.135e-03
# Saved model to /home/stephen/grokking/grok_1764602090/28400.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28410.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28420.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28430.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28440.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28450.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28460.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28470.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28480.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28490.pth
# 28500_-16.0328_-12.3086_pen=3.132e-03
# Saved model to /home/stephen/grokking/grok_1764602090/28500.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28510.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28520.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28530.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28540.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28550.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28560.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28570.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28580.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28590.pth
# 28600_-16.0328_-12.3322_pen=3.130e-03
# Saved model to /home/stephen/grokking/grok_1764602090/28600.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28610.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28620.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28630.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28640.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28650.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28660.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28670.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28680.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28690.pth
# 28700_-16.0329_-12.3540_pen=3.128e-03
# Saved model to /home/stephen/grokking/grok_1764602090/28700.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28710.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28720.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28730.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28740.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28750.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28760.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28770.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28780.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28790.pth
# 28800_-16.0328_-12.3539_pen=3.126e-03
# Saved model to /home/stephen/grokking/grok_1764602090/28800.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28810.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28820.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28830.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28840.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28850.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28860.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28870.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28880.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28890.pth
# 28900_-16.0328_-12.3403_pen=3.125e-03
# Saved model to /home/stephen/grokking/grok_1764602090/28900.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28910.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28920.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28930.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28940.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28950.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28960.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28970.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28980.pth
# Saved model to /home/stephen/grokking/grok_1764602090/28990.pth
# 29000_-16.0330_-12.3364_pen=3.123e-03
# Saved model to /home/stephen/grokking/grok_1764602090/29000.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29010.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29020.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29030.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29040.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29050.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29060.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29070.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29080.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29090.pth
# 29100_-16.0331_-12.3273_pen=3.121e-03
# Saved model to /home/stephen/grokking/grok_1764602090/29100.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29110.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29120.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29130.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29140.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29150.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29160.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29170.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29180.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29190.pth
# 29200_-16.0330_-12.3391_pen=3.119e-03
# Saved model to /home/stephen/grokking/grok_1764602090/29200.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29210.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29220.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29230.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29240.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29250.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29260.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29270.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29280.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29290.pth
# 29300_-16.0332_-12.3591_pen=3.118e-03
# Saved model to /home/stephen/grokking/grok_1764602090/29300.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29310.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29320.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29330.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29340.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29350.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29360.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29370.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29380.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29390.pth
# 29400_-16.0333_-12.3627_pen=3.116e-03
# Saved model to /home/stephen/grokking/grok_1764602090/29400.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29410.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29420.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29430.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29440.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29450.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29460.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29470.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29480.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29490.pth
# 29500_-16.0333_-12.3705_pen=3.114e-03
# Saved model to /home/stephen/grokking/grok_1764602090/29500.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29510.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29520.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29530.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29540.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29550.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29560.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29570.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29580.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29590.pth
# 29600_-16.0335_-12.3962_pen=3.113e-03
# Saved model to /home/stephen/grokking/grok_1764602090/29600.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29610.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29620.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29630.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29640.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29650.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29660.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29670.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29680.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29690.pth
# 29700_-16.0336_-12.4190_pen=3.111e-03
# Saved model to /home/stephen/grokking/grok_1764602090/29700.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29710.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29720.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29730.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29740.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29750.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29760.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29770.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29780.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29790.pth
# 29800_-16.0337_-12.4381_pen=3.109e-03
# Saved model to /home/stephen/grokking/grok_1764602090/29800.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29810.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29820.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29830.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29840.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29850.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29860.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29870.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29880.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29890.pth
# 29900_-16.0339_-12.4673_pen=3.107e-03
# Saved model to /home/stephen/grokking/grok_1764602090/29900.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29910.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29920.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29930.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29940.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29950.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29960.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29970.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29980.pth
# Saved model to /home/stephen/grokking/grok_1764602090/29990.pth
# Saved model to /home/stephen/grokking/grok_1764602090/final.pth

# %% [markdown]
# ## Viz Results

# %%
CHILL_BROWN='#948979'
YELLOW='#ffd35a'
YELLOW_FADE='#7f6a2d'
BLUE='#65c8d0'
GREEN='#6e9671' 
CHILL_GREEN='#6c946f'
CHILL_BLUE='#3d5c6f'
FRESH_TAN='#dfd0b9'
CYAN='#00FFFF'

# %%
plt.plot(train_accs)
plt.plot(test_accs)

# %%
os.mkdir(root/run_name/'accuracy_curves')

# %%
for step in tqdm.tqdm(range(1, len(train_accs))):

    plt.clf()        
    fig=plt.figure(0,(14,6), facecolor='k') 
    ax=fig.add_subplot(111, facecolor='k')
    
    plt.plot(train_accs[:step], c=BLUE, linewidth=2.5, alpha=0.95) #'#dfd0b9')
    plt.plot(test_accs[:step], c=YELLOW, linewidth=2.5, alpha=0.95) #'#dfd0b9')
    plt.tick_params(axis='x', colors='#948979', labelsize=16)  # Add labelsize here
    plt.tick_params(axis='y', colors='#948979', labelsize=16)  # Add labelsize here
    
    plt.gca().spines['top'].set_color('#948979')
    plt.gca().spines['bottom'].set_color('#948979')
    plt.gca().spines['left'].set_color('#948979')
    plt.gca().spines['right'].set_color('#948979')
    plt.subplots_adjust(bottom=0.2)  # Add fixed bottom margin
    # plt.xlim([-10, len(to_plot)+10])
    plt.ylim([0,1.05]) #Bad idea to fix or is it fine?
    plt.grid(True, color='#948979', alpha=0.3)
    plt.savefig(str(root/run_name/'accuracy_curves')+'/'+str(step).zfill(4)+'.png', dpi=400, transparent=True)
# Out:
#   0%|          | 0/29999 [00:00<?, ?it/s]
# /tmp/ipykernel_287232/2332751563.py:4: UserWarning:
#
# Ignoring specified arguments in this call because figure with num: 0 already exists

# %%
# step=15000

# plt.clf()        
# fig=plt.figure(0,(14,6), facecolor='k') 
# ax=fig.add_subplot(111, facecolor='k')

# plt.plot(train_accs[:step], c=BLUE, linewidth=2.5, alpha=0.95) #'#dfd0b9')
# plt.plot(test_accs[:step], c=YELLOW, linewidth=2.5, alpha=0.95) #'#dfd0b9')
# plt.tick_params(axis='x', colors='#948979', labelsize=16)  # Add labelsize here
# plt.tick_params(axis='y', colors='#948979', labelsize=16)  # Add labelsize here

# plt.gca().spines['top'].set_color('#948979')
# plt.gca().spines['bottom'].set_color('#948979')
# plt.gca().spines['left'].set_color('#948979')
# plt.gca().spines['right'].set_color('#948979')
# plt.subplots_adjust(bottom=0.2)  # Add fixed bottom margin
# # plt.xlim([-10, len(to_plot)+10])
# plt.ylim([0,1.05]) #Bad idea to fix or is it fine?
# plt.grid(True, color='#948979', alpha=0.3)
# # plt.savefig(str(root/run_name)+str(step).zfill(4)+'.png', dpi=400, transparent=True)

# %%
step=12000

plt.clf()        
fig=plt.figure(0,(14,6), facecolor='k') 
ax=fig.add_subplot(111, facecolor='k')

plt.plot(np.log10(np.arange(1, 12001)), train_accs[:step], c=BLUE, linewidth=2.5, alpha=0.95) #'#dfd0b9')
plt.plot(np.log10(np.arange(1, 12001)), test_accs[:step], c=YELLOW, linewidth=2.5, alpha=0.95) #'#dfd0b9')
plt.tick_params(axis='x', colors='#948979', labelsize=16)  # Add labelsize here
plt.tick_params(axis='y', colors='#948979', labelsize=16)  # Add labelsize here

plt.gca().spines['top'].set_color('#948979')
plt.gca().spines['bottom'].set_color('#948979')
plt.gca().spines['left'].set_color('#948979')
plt.gca().spines['right'].set_color('#948979')
plt.subplots_adjust(bottom=0.2)  # Add fixed bottom margin
# plt.xlim([-10, len(to_plot)+10])
plt.ylim([0,1.1]) #Bad idea to fix or is it fine?
plt.grid(1) ##Eh not sure
# plt.savefig(str(root/run_name)+str(step).zfill(4)+'.png', dpi=400, transparent=True)

# %%
plt.plot(train_losses)
plt.plot(test_losses)
