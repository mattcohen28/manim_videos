# %%
# %pylab inline
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
fn='/Users/stephen/Stephencwelch Dropbox/welch_labs/bitter_lesson/a_roll/260112_001_Tr1.WAV'

# %%
from scipy.io import wavfile

sample_rate, data = wavfile.read(fn)
# Out:
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3477/2235076078.py:3: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = wavfile.read(fn)

# %%
data.shape, sample_rate
# Out:
# ((1824000,), 48000)

# %%
data
# Out:
# array([ 0.00119837,  0.00130907,  0.00128603, ..., -0.00069473,
#        -0.00076231, -0.00063734], dtype=float32)

# %%
CHILL_BROWN='#948979'

fig=plt.figure(0, (12,4), facecolor='k')
ax=fig.add_subplot(111, facecolor='k')
plt.plot(data[378000:440000], color='#00FFFF')

# Spines
for spine in ax.spines.values():
    spine.set_color(CHILL_BROWN)

# Ticks and tick labels
ax.tick_params(colors=CHILL_BROWN)

# If you have axis labels
ax.xaxis.label.set_color(CHILL_BROWN)
ax.yaxis.label.set_color(CHILL_BROWN)

# If you have a title
ax.title.set_color(CHILL_BROWN)
# plt.grid()
